# %%
import pickle

# %%
with open('dataset/train_update_10t01.pkl', 'rb') as file:
    train_dataset = pickle.load(file)

# %%
train_dataset
# Out:
# [[('Phòng', 'O'),
#   ('khám', 'O'),
#   ('Ts.Bs', 'PERSONTYPE'),
#   ('Long', 'PERSON'),
#   ('chuyên', 'O'),
#   ('khoa', 'O'),
#   ('tim', 'O'),
#   ('mạch', 'O'),
#   ('tại', 'O'),
#   ('Lô', 'ADDRESS'),
#   ('A4', 'ADDRESS'),
#   (',', 'ADDRESS'),
#   ('KCN', 'ADDRESS'),
#   ('Sông', 'ADDRESS'),
#   ('Mây', 'ADDRESS'),
#   (',', 'ADDRESS'),
#   ('Trảng', 'ADDRESS'),
#   ('Bom', 'ADDRESS'),
#   (',', 'ADDRESS'),
#   ('Đồng', 'ADDRESS'),
#   ('Nai', 'ADDRESS'),
#   ('.', 'O'),
#   ('Người', 'O'),
#   ('dân', 'O'),
#   ('có', 'O'),
#   ('thể', 'O'),
#   ('gọi', 'O'),
#   ('số', 'O'),
#   ('+84947455566', 'PHONENUMBER'),
#   ('để', 'O'),
#   ('đặt', 'O'),
#   ('lịch', 'O'),
#   ('khám', 'O'),
#   ('bệnh', 'O'),
#   ('.', 'O')],
#  [('Sáng', 'DATETIME'),
#   ('30-6', 'DATETIME'),
#   (',', 'O'),
#   ('văn', 'O'),
#   ('phòng', 'O'),
#   ('đại', 'O'),
#   ('diện', 'O'),
#   ('báo', 'ORGANIZATION'),
#   ('Tuổi', 'ORGANIZATION'),
#   ('Trẻ', 'ORGANIZATION'),
#   ('tại', 'O'),
# ...

# %%
test_dataset[0]
# Out:
# [('Trong', 'O'),
#  ('đó', 'O'),
#  (',', 'O'),
#  ('nhân', 'O'),
#  ('viên', 'O'),
#  ('của', 'O'),
#  ('quán', 'O'),
#  ('là', 'O'),
#  ('Võ', 'PERSON'),
#  ('Văn', 'PERSON'),
#  ('Hùng', 'PERSON'),
#  ('(', 'O'),
#  ('17', 'QUANTITY'),
#  ('tuổi', 'QUANTITY'),
#  (',', 'O'),
#  ('ngụ', 'O'),
#  ('Tầng', 'ADDRESS'),
#  ('trệt', 'ADDRESS'),
#  (',', 'ADDRESS'),
#  ('nhà', 'ADDRESS'),
#  ('dịch', 'ADDRESS'),
#  ('vụ', 'ADDRESS'),
#  ('Số', 'ADDRESS'),
#  ('L2-SH.06', 'ADDRESS'),
#  (',', 'ADDRESS'),
#  ('chung', 'ADDRESS'),
#  ('cư', 'ADDRESS'),
#  ('Lanmark', 'ADDRESS'),
#  ('2', 'ADDRESS'),
#  (',', 'ADDRESS'),
#  ('đường', 'ADDRESS'),
#  ('Điện', 'ADDRESS'),
#  ('Biên', 'ADDRESS'),
#  ('Phủ', 'ADDRESS'),
#  (',', 'ADDRESS'),
#  ('Phường', 'ADDRESS'),
#  ('22', 'ADDRESS'),
#  (',', 'ADDRESS'),
#  ('Bình', 'ADDRESS'),
#  ('Thạnh', 'ADDRESS'),
#  (',', 'ADDRESS'),
#  ('Hồ', 'ADDRESS'),
#  ('Chí', 'ADDRESS'),
#  ('Minh', 'ADDRESS'),
#  (')', 'O'),
#  ('bị', 'O'),
#  ('đánh', 'O'),
# ...
